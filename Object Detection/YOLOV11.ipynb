# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.168 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.9/107.7 GB disk)

# %%
#visualize the predicted image
import cv2
from google.colab.patches import cv_imshow

def image_show(file_path):
  image = cv2.imread(file_path)
  cv_imshow(image)

# %%
#Inferebcing with YOLOv11 pretrained model
# !yolo predict model = yolo11n.pt source = "https://machinelearningmastery.com/wp-content/uploads/2023/12/adria-crehuet-cano-LIhB1_mAGhY-unsplash-scaled.jpg"
# Out:
# Ultralytics 8.3.168 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# ...
# 100% 405k/405k [00:00<00:00, 45.9MB/s]
# image 1/1 /content/adria-crehuet-cano-LIhB1_mAGhY-unsplash-scaled.jpg: 448x640 9 persons, 1 frisbee, 201.9ms
# Speed: 5.8ms preprocess, 201.9ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
image_show("/content/runs/detect/predict2/adria-crehuet-cano-LIhB1_mAGhY-unsplash-scaled.jpg")
# Out:
# Output hidden; open in https://colab.research.google.com to view.
