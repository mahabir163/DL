# %%
#package installation
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 24.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 85.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 63.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 63.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 18.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
#Detection
from ultralytics import YOLO
model = YOLO("yolo11n.pt")

# %%
#tracking
result = model.track(source="https://www.youtube.com/watch?v=Y1jTEyb3wiI",conf=0.3,iou=0.5,save=True)
# Out:
# 1/1: https://www.youtube.com/watch?v=Y1jTEyb3wiI... Success ✅ (716 frames of shape 1920x1080 at 29.97 FPS)
#
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 384x640 1 person, 8 cars, 1 truck, 485.8ms
# 0: 384x640 1 person, 3 cars, 15.9ms
# 0: 384x640 1 person, 4 cars, 27.2ms
# 0: 384x640 1 person, 3 cars, 27.2ms
# 0: 384x640 1 person, 3 cars, 14.9ms
# 0: 384x640 1 person, 2 cars, 19.0ms
# 0: 384x640 1 person, 3 cars, 18.9ms
# 0: 384x640 1 person, 4 cars, 1 truck, 15.2ms
# ...

# %%
result = model.track(source="https://www.youtube.com/watch?v=Y1jTEyb3wiI",tracker="bytetrack.yaml",save=True)
# Out:
# 1/1: https://www.youtube.com/watch?v=Y1jTEyb3wiI... Success ✅ (716 frames of shape 1920x1080 at 29.97 FPS)
#
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 384x640 2 cars, 37.1ms
# 0: 384x640 1 person, 3 cars, 1 truck, 16.8ms
# 0: 384x640 1 person, 2 cars, 27.0ms
# 0: 384x640 1 person, 28.6ms
# 0: 384x640 1 person, 25.4ms
# 0: 384x640 1 person, 28.8ms
# 0: 384x640 1 person, 26.2ms
# 0: 384x640 1 person, 15.3ms
# 0: 384x640 1 person, 27.0ms
# 0: 384x640 1 person, 20.5ms
# ...
